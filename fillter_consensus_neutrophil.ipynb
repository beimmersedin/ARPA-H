# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터 정제

# %%
# 1. DEG_Wilcoxon 전처리 
# Wilcoxon_DEG : Wilcoxon_DEG_~.csv

df_wilcoxon = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_Wilcoxon/Wilcoxon_DEG_neutrophil_re.csv')
print(df_wilcoxon.shape)
print(df_wilcoxon.head())
df_wilcoxon = df_wilcoxon[["names", "logfoldchanges", "pvals", "pvals_adj"]]
df_wilcoxon.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "Wilcoxon_adj_pval"}, inplace=True)
print(df_wilcoxon.head())
# Out:
# (448, 5)
#     names     scores  logfoldchanges          pvals      pvals_adj
# 0  MALAT1  35.886555        0.478487  4.951024e-282  5.545147e-280
# 1   NEAT1  35.141605        0.611005  1.561759e-270  1.399336e-268
# 2   CXCL8  31.870878        0.546614  6.763697e-223  5.050227e-221
# 3     B2M  28.256105        0.296057  1.197543e-175  5.961102e-174
# 4    SRGN  28.191143        0.612946  7.508914e-175  3.363994e-173
#      gene  logfoldchanges           pval  Wilcoxon_adj_pval
# 0  MALAT1        0.478487  4.951024e-282      5.545147e-280
# 1   NEAT1        0.611005  1.561759e-270      1.399336e-268
# 2   CXCL8        0.546614  6.763697e-223      5.050227e-221
# 3     B2M        0.296057  1.197543e-175      5.961102e-174
# 4    SRGN        0.612946  7.508914e-175      3.363994e-173

# %%
df_wilcoxon.head(2)
# Out:
#      gene  logfoldchanges           pval  Wilcoxon_adj_pval
# 0  MALAT1        0.478487  4.951024e-282      5.545147e-280
# 1   NEAT1        0.611005  1.561759e-270      1.399336e-268

# %%
# 2. DEG_limatrend 전처리 
# limatrend_DEG : limmatrend_DEG_~.csv

df_limmatrend = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_limmatrend/limmatrend_DEG_neutrophil_re.csv')
print(df_limmatrend.shape)
print(df_limmatrend.head(2))
df_limmatrend = df_limmatrend[["names", "logfolchanges", "pvals", "pvals_adj"]]
print((df_limmatrend.head()))
df_limmatrend.rename(columns={"names": "gene", "logfolchanges": "logfoldchanges", "pvals": "pval","pvals_adj": "limmatrend_adj_pval"}, inplace=True)
print(df_limmatrend.head())
# Out:
# (448, 6)
#      names          pvals      pvals_adj  logfolchanges  neglog10_pvalue  \
# 0  GABARAP  4.940656e-324  4.940656e-324       1.366420              NaN
# 1   IFITM2  4.940656e-324  4.940656e-324       1.585198              NaN
#
#    neglog10_adjpvalue
# 0                 NaN
# 1                 NaN
#      names  logfolchanges          pvals      pvals_adj
# 0  GABARAP       1.366420  4.940656e-324  4.940656e-324
# 1   IFITM2       1.585198  4.940656e-324  4.940656e-324
# 2   TYROBP       1.130992  4.940656e-324  4.940656e-324
# 3   RNASEK       1.108302  4.940656e-324  4.940656e-324
# 4   IFITM1       1.251519  4.940656e-324  4.940656e-324
#       gene  logfoldchanges           pval  limmatrend_adj_pval
# 0  GABARAP        1.366420  4.940656e-324        4.940656e-324
# 1   IFITM2        1.585198  4.940656e-324        4.940656e-324
# 2   TYROBP        1.130992  4.940656e-324        4.940656e-324
# 3   RNASEK        1.108302  4.940656e-324        4.940656e-324
# 4   IFITM1        1.251519  4.940656e-324        4.940656e-324

# %%
df_limmatrend.head(2)
# Out:
#       gene  logfoldchanges           pval  limmatrend_adj_pval
# 0  GABARAP        1.366420  4.940656e-324        4.940656e-324
# 1   IFITM2        1.585198  4.940656e-324        4.940656e-324

# %%
# 3. RISCQP_DEG 전처리
# DEG_RISCQP : RISCQP_DEG_-.csv

df_RISCQP = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_RISCQP/RISCQP_DEG_neutrophil_re.csv')
print(df_RISCQP.shape)
print(df_RISCQP.head())
df_RISCQP = df_RISCQP[["Symbol", "log2FC", "Pvalue", "Padj"]]
df_RISCQP.rename(columns={"Symbol": "gene","Pvalue": "pval","Padj": "RISCQP_adj_pval"}, inplace=True)
print(df_RISCQP.head())
# Out:
# (448, 10)
#   Unnamed: 0   Symbol  Percent  Pct.Ctl  Pct.Sam  avelog.Ctl  avelog.Sam  \
# 0    GABARAP  GABARAP    0.649    0.733    0.148    1.262491    6.343547
# 1     IFITM1   IFITM1    0.593    0.665    0.159    1.379372    5.781067
# 2     RNASEK   RNASEK    0.576    0.648    0.141    1.198536    5.564002
# 3     TYROBP   TYROBP    0.847    0.891    0.583    5.123835    7.863762
# 4     IFITM2   IFITM2    0.925    0.949    0.781    7.065035    8.740628
#
#      log2FC         Pvalue           Padj
# 0  7.807727   0.000000e+00   0.000000e+00
# 1  6.764227  1.624824e-279  3.639607e-277
# 2  6.810444  9.214941e-273  1.376098e-270
# 3  3.960939  1.055650e-230  1.182328e-228
# 4  2.418373  7.473909e-152  6.696623e-150
#       gene    log2FC           pval  RISCQP_adj_pval
# 0  GABARAP  7.807727   0.000000e+00     0.000000e+00
# 1   IFITM1  6.764227  1.624824e-279    3.639607e-277
# 2   RNASEK  6.810444  9.214941e-273    1.376098e-270
# 3   TYROBP  3.960939  1.055650e-230    1.182328e-228
# 4   IFITM2  2.418373  7.473909e-152    6.696623e-150

# %%
df_RISCQP.head(2)
# Out:
#       gene    log2FC           pval  RISCQP_adj_pval
# 0  GABARAP  7.807727   0.000000e+00     0.000000e+00
# 1   IFITM1  6.764227  1.624824e-279    3.639607e-277

# %%
# 4. monocle_deg 전처리
# DEG_monocle : monocle_DEG_-.csv

df_monocle = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_monocle/monocle_DEG_neutrophil.csv')
print(df_monocle.shape)
print(df_monocle.head())
df_monocle = df_monocle[["gene", "log2FC", "pvalue", "adjpvalue"]]
df_monocle.rename(columns={"pvalue": "pval","adjpvalue": "monocle_adj_pval"}, inplace=True)
print(df_monocle.head())
# Out:
# (448, 13)
#    X     gene  num_cells_expressed          gene_id status      term  \
# 0  1  GABARAP                 7972  ENSG00000170296     OK  GroupMSI
# 1  2     CD44                 4338  ENSG00000026508     OK  GroupMSI
# 2  3   RNASEK                 7067  ENSG00000219200     OK  GroupMSI
# 3  4   IFITM1                 7279  ENSG00000185885     OK  GroupMSI
# 4  5      MIF                 4502  ENSG00000240972     OK  GroupMSI
#
#      log2FC   std_err   test_val         pvalue  normalized_effect  \
# 0 -1.733665  0.065888 -26.312215  1.390064e-152          -2.423122
# 1  0.913968  0.036493  25.044877  1.985299e-138           1.291402
# 2 -1.649120  0.068446 -24.093615  2.916258e-128          -2.296709
# 3 -1.376648  0.060642 -22.701399  4.339694e-114          -1.931171
# 4 -1.519436  0.072120 -21.068111   1.560344e-98          -2.091585
#
#   model_component      adjpvalue
# 0           count  6.227488e-150
# 1           count  8.874287e-136
# 2           count  1.300651e-125
# 3           count  1.931164e-111
# 4           count   6.927929e-96
#       gene    log2FC           pval  monocle_adj_pval
# 0  GABARAP -1.733665  1.390064e-152     6.227488e-150
# 1     CD44  0.913968  1.985299e-138     8.874287e-136
# 2   RNASEK -1.649120  2.916258e-128     1.300651e-125
# 3   IFITM1 -1.376648  4.339694e-114     1.931164e-111
# 4      MIF -1.519436   1.560344e-98      6.927929e-96

# %%
df_monocle.head(2)
# Out:
#       gene    log2FC           pval  monocle_adj_pval
# 0  GABARAP -1.733665  1.390064e-152     6.227488e-150
# 1     CD44  0.913968  1.985299e-138     8.874287e-136

# %%
# 5. DEG_MAST 전처리 
# MAST_DEG : MAST_DEG_~.csv

df_MAST = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_MAST/MAST_DEG_neutrophil.csv')
print(df_MAST.shape)
print(df_MAST.head(2))
# df_MAST = df_MAST[["names", "logfoldchanges", "pvals", "pvals_adj"]]
# print((df_MAST.head()))
df_MAST.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "MAST_adj_pval"}, inplace=True)
print(df_MAST.head())
# Out:
# (448, 4)
#    names  logfoldchanges         pvals     pvals_adj
# 0  ABHD5        0.178869  6.282769e-22  1.182639e-21
# 1  ACAP2        0.207242  1.103002e-33  2.906734e-33
#     gene  logfoldchanges          pval  MAST_adj_pval
# 0  ABHD5        0.178869  6.282769e-22   1.182639e-21
# 1  ACAP2        0.207242  1.103002e-33   2.906734e-33
# 2  ACSL1       -0.043140  2.226236e-07   2.833391e-07
# 3   ACTB        0.345049  9.136313e-46   3.172921e-45
# 4  ACTG1        0.338769  4.542085e-49   1.769438e-48

# %%
df_MAST.head(2)
# Out:
#     gene  logfoldchanges          pval  MAST_adj_pval
# 0  ABHD5        0.178869  6.282769e-22   1.182639e-21
# 1  ACAP2        0.207242  1.103002e-33   2.906734e-33

# %% [markdown]
# ## <font color="red">**MSS/MSI 데이터프레임**

# %%
import pandas as pd
from functools import reduce

# 1) 미리 각 df에서 gene + adj_pval 컬럼만 추출
dfs = [
    df_wilcoxon[["gene", "Wilcoxon_adj_pval"]],
    df_limmatrend[["gene", "limmatrend_adj_pval"]],
    df_RISCQP[["gene", "RISCQP_adj_pval"]],
    df_MAST[["gene", "MAST_adj_pval"]],
    df_monocle[["gene", "monocle_adj_pval"]],
]

# 2) Reduce를 이용해 순차적으로 outer merge
df_mmm = reduce(
    lambda left, right: pd.merge(left, right, on="gene", how="outer"),
    dfs
)

# 결과 확인
print(df_mmm.shape)
print(df_mmm.head())
# Out:
# (448, 6)
#     gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0  ABHD5       3.751912e-09         1.023907e-19     1.155939e-15
# 1  ACAP2       1.808067e-15         3.535329e-28     2.794164e-22
# 2  ACSL1       6.786679e-04         9.421506e-02     1.010783e-04
# 3   ACTB       9.894593e-01         2.499263e-26     7.764466e-01
# 4  ACTG1       1.395776e-13         1.167128e-30     1.090186e-10
#
#    MAST_adj_pval  monocle_adj_pval
# 0   1.182639e-21      6.540115e-06
# 1   2.906734e-33      2.954528e-08
# 2   2.833391e-07      1.747499e-11
# 3   3.172921e-45      1.000000e+00
# 4   1.769438e-48      1.000000e+00

# %%
df_mmm.head(2)
# Out:
#     gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0  ABHD5       3.751912e-09         1.023907e-19     1.155939e-15
# 1  ACAP2       1.808067e-15         3.535329e-28     2.794164e-22
#
#    MAST_adj_pval  monocle_adj_pval
# 0   1.182639e-21      6.540115e-06
# 1   2.906734e-33      2.954528e-08

# %%
# 1) 각 컬럼별 rank 계산 (값이 작을수록 1위, NaN은 가장 마지막)
df_mmm['rank_wilcoxon'] = df_mmm['Wilcoxon_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_limma'] = df_mmm['limmatrend_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_RISCQP'] = df_mmm['RISCQP_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_MAST'] = df_mmm['MAST_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_monocle'] = df_mmm['monocle_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

# 2) 5개 rank의 합 계산
df_mmm['rank_sum'] = df_mmm[
    ['rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']
].sum(axis=1)

# 3) sum_rank 기준으로 정렬
df_mmm = df_mmm.sort_values('rank_sum').reset_index(drop=True)

# 결과 확인 (선택사항)
df_mmm
# Out:
#         gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0    GABARAP       0.000000e+00        4.940656e-324     0.000000e+00
# 1     IFITM1       0.000000e+00        4.940656e-324    3.639607e-277
# 2     RNASEK      1.493199e-296        4.940656e-324    1.376098e-270
# 3     CCL4L2      1.217853e-174        8.107194e-211    3.098718e-121
# 4     TYROBP      1.755930e-160        4.940656e-324    1.182328e-228
# ..       ...                ...                  ...              ...
# 443      TXN       9.512370e-02         7.859474e-01     6.504103e-01
# 444     MAFF       7.420515e-01         2.748585e-01     6.304707e-01
# 445    CYRIB       2.126246e-01         1.772746e-01     7.699303e-01
# 446     GUK1       7.124989e-01         8.160667e-02     6.367603e-01
# 447   IL1RAP       4.192632e-01         6.642777e-01     6.797160e-01
#
#      MAST_adj_pval  monocle_adj_pval  rank_wilcoxon  rank_limma  rank_RISCQP  \
# 0         0.000000     6.227488e-150              1           1            1
# 1         0.000000     1.931164e-111              1           1            2
# 2         0.000000     1.300651e-125              3           1            3
# 3         0.000000      2.941699e-92              8           9           11
# 4         0.000000      4.028134e-45             12           1            4
# ..             ...               ...            ...         ...          ...
# 443       0.119002      1.000000e+00            386         438          432
# 444       0.451649      4.173930e-02            437         425          429
# 445       0.259052      1.000000e+00            401         417          442
# 446       0.023296      1.000000e+00            436         407          430
# 447       0.367363      1.000000e+00            417         436          436
#
#      rank_MAST  rank_monocle  rank_sum
# 0            1             1         5
# 1            1             4         9
# 2            1             3        11
# 3            1             6        35
# 4            1            25        43
# ..         ...           ...       ...
# 443        433           311      2000
# 444        444           270      2005
# 445        436           311      2007
# 446        426           311      2010
# 447        440           311      2040
#
# [448 rows x 12 columns]

# %%
df_mmm_re = df_mmm[['rank_sum', 'gene', 'rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']]
df_mmm_re.head(20)
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST
# 0          5  GABARAP              1           1            1          1
# 1          9   IFITM1              1           1            2          1
# 2         11   RNASEK              3           1            3          1
# 3         35   CCL4L2              8           9           11          1
# 4         43   TYROBP             12           1            4          1
# 5         50   IFITM2              7           1            5          1
# 6         56  ATP6V0C             15          13            9         11
# 7         62     CD44             13          16            6         25
# 8         64    IFI30             14          18            8         14
# 9         86   IFITM3             16          11           12         16
# 10        93     LSP1             18          20           10         19
# 11        95      FOS             21          10            7         18
# 12       103      MIF             29          27           19         23
# 13       104    ALDOA             22          25           14         21
# 14       105    BEST1             26          24           14         20
# 15       109     FPR1             20          21           13         26
# 16       132  SEC14L1             25          28           20         29
# 17       133    YPEL3             27          29           18         27
# 18       151   TAGLN2             24          26           24         24
# 19       155    ITM2B             23          12           17         15

# %%
# 원하는 순서의 리스트
genes_of_interest = ["VSIG4", "LYVE1", "CLEC5A", "CX3CR1", "FN1", "IL11", "NRAP", "SDC1", "SCG5"]
df_mmm_re_filtered = df_mmm_re[df_mmm_re["gene"].isin(genes_of_interest)]
df_mmm_re_filtered
# Out:
# Empty DataFrame
# Columns: [rank_sum, gene, rank_wilcoxon, rank_limma, rank_RISCQP, rank_MAST]
# Index: []
