# %%
yeonu@gpusystem:/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output$ pwd
/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output
yeonu@gpusystem:/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output$ ls
filtered_B_cell_count__MSI_stats.csv       raw_B_cell_count__MSI_stats.csv
filtered_B_cell_count__MSS_stats.csv       raw_B_cell_count__MSS_stats.csv
filtered_Epithelial_count__MSI_stats.csv   raw_Epithelial_count__MSI_stats.csv
filtered_Epithelial_count__MSS_stats.csv   raw_Epithelial_count__MSS_stats.csv
filtered_mast_count__MSI_stats.csv         raw_Mast_cell_count__MSI_stats.csv
filtered_mast_count__MSS_stats.csv         raw_Mast_cell_count__MSS_stats.csv
filtered_myeloid_count__MSI_stats.csv      raw_myeloid_count__MSI_stats.csv
filtered_myeloid_count__MSS_stats.csv      raw_myeloid_count__MSS_stats.csv
filtered_neutrophil_count__MSI_stats.csv   raw_neutrophil_count__MSI_stats.csv
filtered_neutrophil_count__MSS_stats.csv   raw_neutrophil_count__MSS_stats.csv
filtered_Plasma_cell_count__MSI_stats.csv  raw_plasma_count__MSI_stats.csv
filtered_Plasma_cell_count__MSS_stats.csv  raw_plasma_count__MSS_stats.csv
filtered_random10_count__MSI_stats.csv     raw_random10_count__MSI_stats.csv
filtered_random10_count__MSS_stats.csv     raw_random10_count__MSS_stats.csv
filtered_stromal_count__MSI_stats.csv      raw_stromal_count__MSI_stats.csv
filtered_stromal_count__MSS_stats.csv      raw_stromal_count__MSS_stats.csv
yeonu@gpusystem:/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output$

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # random10

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_random10_count__MSI_stats.csv'

print('raw_random10_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_random10_count__MSS_stats.csv'

print('raw_random10_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_random10_count__MSI_stats.csv
#      gene      mean    median
# 0   VSIG4  0.001395  0.000000
# 1   LYVE1  0.024153  0.000000
# 2  CLEC5A  0.001222  0.000000
# 3  CX3CR1  0.000000  0.000000
# 4     FN1  0.094255  0.000000
# 5    IL11  0.000934  0.000000
# 6    NRAP  0.000549  0.000000
# 7    SDC1  0.119899  0.062194
# 8    SCG5  0.030252  0.000000
#
# raw_random10_count__MSS_stats.csv
#      gene      mean    median
# 0   VSIG4  0.000737  0.000000
# 1   LYVE1  0.000224  0.000000
# 2  CLEC5A  0.000470  0.000000
# 3  CX3CR1  0.000432  0.000000
# 4     FN1  0.220084  0.000000
# 5    IL11  0.004522  0.000000
# 6    NRAP  0.000044  0.000000
# 7    SDC1  0.175971  0.122352
# 8    SCG5  0.013679  0.000000

# %%
######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_random10_count__MSI_stats.csv'

print('filtered_random10_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_random10_count__MSS_stats.csv'

print('filtered_random10_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_random10_count__MSI_stats.csv
#      gene      mean    median
# 0   VSIG4       NaN       NaN
# 1   LYVE1       NaN       NaN
# 2  CLEC5A       NaN       NaN
# 3  CX3CR1       NaN       NaN
# 4     FN1       NaN       NaN
# 5    IL11       NaN       NaN
# 6    NRAP       NaN       NaN
# 7    SDC1  0.119899  0.062194
# 8    SCG5       NaN       NaN
#
# filtered_random10_count__MSS_stats.csv
#      gene      mean    median
# 0   VSIG4       NaN       NaN
# 1   LYVE1       NaN       NaN
# 2  CLEC5A       NaN       NaN
# 3  CX3CR1       NaN       NaN
# 4     FN1       NaN       NaN
# 5    IL11       NaN       NaN
# 6    NRAP       NaN       NaN
# 7    SDC1  0.175971  0.122352
# 8    SCG5       NaN       NaN

# %% [markdown]
# # myeloid

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_myeloid_count__MSI_stats.csv'

print('raw_myeloid_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_myeloid_count__MSS_stats.csv'

print('raw_myeloid_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_myeloid_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.027857     0.0
# 1   LYVE1  0.000900     0.0
# 2  CLEC5A  0.033320     0.0
# 3  CX3CR1  0.138863     0.0
# 4     FN1  0.022736     0.0
# 5    IL11  0.000042     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.000220     0.0
# 8    SCG5  0.001110     0.0
#
# raw_myeloid_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.285683     0.0
# 1   LYVE1  0.050528     0.0
# 2  CLEC5A  0.085124     0.0
# 3  CX3CR1  0.039786     0.0
# 4     FN1  0.157021     0.0
# 5    IL11  0.000296     0.0
# 6    NRAP  0.000017     0.0
# 7    SDC1  0.003111     0.0
# 8    SCG5  0.001485     0.0

# %%
######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_myeloid_count__MSI_stats.csv'

print('filtered_myeloid_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_myeloid_count__MSS_stats.csv'

print('filtered_myeloid_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_myeloid_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.027857     0.0
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1       NaN     NaN
# 8    SCG5       NaN     NaN
#
# filtered_myeloid_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.285683     0.0
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1       NaN     NaN
# 8    SCG5       NaN     NaN

# %% [markdown]
# # Epithelial

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_Epithelial_count__MSI_stats.csv'

print('raw_Epithelial_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)


######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_Epithelial_count__MSS_stats.csv'

print('raw_Epithelial_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_Epithelial_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000894     0.0
# 1   LYVE1  0.000750     0.0
# 2  CLEC5A  0.000076     0.0
# 3  CX3CR1  0.000089     0.0
# 4     FN1  0.036685     0.0
# 5    IL11  0.000375     0.0
# 6    NRAP  0.001338     0.0
# 7    SDC1  0.071077     0.0
# 8    SCG5  0.002552     0.0
#
# raw_Epithelial_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000120     0.0
# 1   LYVE1  0.000032     0.0
# 2  CLEC5A  0.000000     0.0
# 3  CX3CR1  0.000279     0.0
# 4     FN1  0.037555     0.0
# 5    IL11  0.000817     0.0
# 6    NRAP  0.000929     0.0
# 7    SDC1  0.108066     0.0
# 8    SCG5  0.004033     0.0

# %%
######################################################################

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_Epithelial_count__MSI_stats.csv'

print('filtered_Epithelial_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_Epithelial_count__MSS_stats.csv'

print('filtered_Epithelial_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_Epithelial_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4       NaN     NaN
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1  0.071077     0.0
# 8    SCG5       NaN     NaN
#
# filtered_Epithelial_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4       NaN     NaN
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1  0.108066     0.0
# 8    SCG5       NaN     NaN

# %% [markdown]
# # neutrophil

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_neutrophil_count__MSI_stats.csv'

print('raw_neutrophil_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)


######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_neutrophil_count__MSS_stats.csv'

print('raw_neutrophil_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_neutrophil_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.003193     0.0
# 1   LYVE1  0.000000     0.0
# 2  CLEC5A  0.022995     0.0
# 3  CX3CR1  0.026838     0.0
# 4     FN1  0.010004     0.0
# 5    IL11  0.001296     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.001204     0.0
# 8    SCG5  0.000000     0.0
#
# raw_neutrophil_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.002390     0.0
# 1   LYVE1  0.000832     0.0
# 2  CLEC5A  0.024134     0.0
# 3  CX3CR1  0.001825     0.0
# 4     FN1  0.015020     0.0
# 5    IL11  0.000124     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.003007     0.0
# 8    SCG5  0.000000     0.0

# %%
######################################################################

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_neutrophil_count__MSI_stats.csv'

print('filtered_neutrophil_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_neutrophil_count__MSS_stats.csv'

print('filtered_neutrophil_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_neutrophil_count__MSI_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN
#
# filtered_neutrophil_count__MSS_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN

# %% [markdown]
# # stromal

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_stromal_count__MSI_stats.csv'

print('raw_stromal_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)


######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_stromal_count__MSS_stats.csv'

print('raw_stromal_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_stromal_count__MSI_stats.csv
#      gene      mean   median
# 0   VSIG4  0.000176  0.00000
# 1   LYVE1  0.013100  0.00000
# 2  CLEC5A  0.000182  0.00000
# 3  CX3CR1  0.000122  0.00000
# 4     FN1  0.758640  0.56409
# 5    IL11  0.052905  0.00000
# 6    NRAP  0.000000  0.00000
# 7    SDC1  0.014631  0.00000
# 8    SCG5  0.010122  0.00000
#
# raw_stromal_count__MSS_stats.csv
#      gene      mean    median
# 0   VSIG4  0.000406  0.000000
# 1   LYVE1  0.019616  0.000000
# 2  CLEC5A  0.000307  0.000000
# 3  CX3CR1  0.000537  0.000000
# 4     FN1  0.899860  0.638353
# 5    IL11  0.007926  0.000000
# 6    NRAP  0.000143  0.000000
# 7    SDC1  0.015203  0.000000
# 8    SCG5  0.016673  0.000000

# %%
######################################################################

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_stromal_count__MSI_stats.csv'

print('filtered_stromal_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_stromal_count__MSS_stats.csv'

print('filtered_stromal_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_stromal_count__MSI_stats.csv
#      gene     mean   median
# 0   VSIG4      NaN      NaN
# 1   LYVE1      NaN      NaN
# 2  CLEC5A      NaN      NaN
# 3  CX3CR1      NaN      NaN
# 4     FN1  0.75864  0.56409
# 5    IL11      NaN      NaN
# 6    NRAP      NaN      NaN
# 7    SDC1      NaN      NaN
# 8    SCG5      NaN      NaN
#
# filtered_stromal_count__MSS_stats.csv
#      gene     mean    median
# 0   VSIG4      NaN       NaN
# 1   LYVE1      NaN       NaN
# 2  CLEC5A      NaN       NaN
# 3  CX3CR1      NaN       NaN
# 4     FN1  0.89986  0.638353
# 5    IL11      NaN       NaN
# 6    NRAP      NaN       NaN
# 7    SDC1      NaN       NaN
# 8    SCG5      NaN       NaN

# %% [markdown]
# # mast

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_Mast_cell_count__MSI_stats.csv'

print('raw_Mast_cell_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_Mast_cell_count__MSS_stats.csv'

print('raw_Mast_cell_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_Mast_cell_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000000     0.0
# 1   LYVE1  0.000944     0.0
# 2  CLEC5A  0.000000     0.0
# 3  CX3CR1  0.000000     0.0
# 4     FN1  0.007117     0.0
# 5    IL11  0.002428     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.004079     0.0
# 8    SCG5  0.000985     0.0
#
# raw_Mast_cell_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.001586     0.0
# 1   LYVE1  0.000000     0.0
# 2  CLEC5A  0.000555     0.0
# 3  CX3CR1  0.000000     0.0
# 4     FN1  0.017205     0.0
# 5    IL11  0.001662     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.005373     0.0
# 8    SCG5  0.003286     0.0

# %%
######################################################################

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_mast_count__MSI_stats.csv'

print('filtered_mast_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_mast_count__MSS_stats.csv'

print('filtered_mast_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_mast_count__MSI_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN
#
# filtered_mast_count__MSS_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN

# %% [markdown]
# # plasma

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_plasma_count__MSI_stats.csv'

print('raw_plasma_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_plasma_count__MSS_stats.csv'

print('raw_plasma_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_plasma_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000118     0.0
# 1   LYVE1  0.000000     0.0
# 2  CLEC5A  0.000053     0.0
# 3  CX3CR1  0.000097     0.0
# 4     FN1  0.028404     0.0
# 5    IL11  0.000479     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.281367     0.0
# 8    SCG5  0.000334     0.0
#
# raw_plasma_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000106     0.0
# 1   LYVE1  0.000293     0.0
# 2  CLEC5A  0.000310     0.0
# 3  CX3CR1  0.000101     0.0
# 4     FN1  0.006089     0.0
# 5    IL11  0.000427     0.0
# 6    NRAP  0.000078     0.0
# 7    SDC1  0.296558     0.0
# 8    SCG5  0.000592     0.0

# %%
######################################################################

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_Plasma_cell_count__MSI_stats.csv'

print('filtered_Plasma_cell_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_Plasma_cell_count__MSS_stats.csv'

print('filtered_Plasma_cell_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_Plasma_cell_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4       NaN     NaN
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1  0.281367     0.0
# 8    SCG5       NaN     NaN
#
# filtered_Plasma_cell_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4       NaN     NaN
# 1   LYVE1       NaN     NaN
# 2  CLEC5A       NaN     NaN
# 3  CX3CR1       NaN     NaN
# 4     FN1       NaN     NaN
# 5    IL11       NaN     NaN
# 6    NRAP       NaN     NaN
# 7    SDC1  0.296558     0.0
# 8    SCG5       NaN     NaN

# %% [markdown]
# # B cell

# %%
file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_B_cell_count__MSI_stats.csv'

print('raw_B_cell_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/raw_B_cell_count__MSS_stats.csv'

print('raw_B_cell_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')
print(df)
# Out:
# raw_B_cell_count__MSI_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000049     0.0
# 1   LYVE1  0.000008     0.0
# 2  CLEC5A  0.000047     0.0
# 3  CX3CR1  0.003614     0.0
# 4     FN1  0.002757     0.0
# 5    IL11  0.000018     0.0
# 6    NRAP  0.000000     0.0
# 7    SDC1  0.001384     0.0
# 8    SCG5  0.000000     0.0
#
# raw_B_cell_count__MSS_stats.csv
#      gene      mean  median
# 0   VSIG4  0.000980     0.0
# 1   LYVE1  0.000386     0.0
# 2  CLEC5A  0.000326     0.0
# 3  CX3CR1  0.000783     0.0
# 4     FN1  0.006274     0.0
# 5    IL11  0.000236     0.0
# 6    NRAP  0.000027     0.0
# 7    SDC1  0.004308     0.0
# 8    SCG5  0.000382     0.0

# %%
######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_B_cell_count__MSI_stats.csv'

print('filtered_B_cell_count__MSI_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)

######################################################################
print()

file_path = '/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/mss_msi_output/filtered_B_cell_count__MSI_stats.csv'

print('filtered_B_cell_count__MSS_stats.csv')

# (예시1) 헤더가 두 번째 줄, 탭 구분자일 때
df = pd.read_csv(file_path, sep='\t', header=1)

# (예시2) 소수점 구분에 콤마 사용( thousands=',' ), 기본 구분자가 콤마일 때 
df = pd.read_csv(file_path, thousands=',')  
print(df)
# Out:
# filtered_B_cell_count__MSI_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN
#
# filtered_B_cell_count__MSS_stats.csv
#      gene  mean  median
# 0   VSIG4   NaN     NaN
# 1   LYVE1   NaN     NaN
# 2  CLEC5A   NaN     NaN
# 3  CX3CR1   NaN     NaN
# 4     FN1   NaN     NaN
# 5    IL11   NaN     NaN
# 6    NRAP   NaN     NaN
# 7    SDC1   NaN     NaN
# 8    SCG5   NaN     NaN
