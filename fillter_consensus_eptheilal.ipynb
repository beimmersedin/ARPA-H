# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 정제

# %%
# 1. DEG_Wilcoxon 전처리 
# Wilcoxon_DEG : Wilcoxon_DEG_~.csv

df_wilcoxon = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_Wilcoxon/Wilcoxon_DEG_epithelial_re.csv')
print(df_wilcoxon.shape)
print(df_wilcoxon.head())
df_wilcoxon = df_wilcoxon[["names", "logfoldchanges", "pvals", "pvals_adj"]]
df_wilcoxon.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "Wilcoxon_adj_pval"}, inplace=True)
print(df_wilcoxon.head())
# Out:
# (3144, 5)
#      names     scores  logfoldchanges          pvals      pvals_adj
# 0  MT-ND4L  48.241734        3.637189   0.000000e+00   0.000000e+00
# 1  MT-ATP8  46.419098        3.875587   0.000000e+00   0.000000e+00
# 2   MT-ND6  36.489178        3.291033  1.646604e-291  1.725641e-288
# 3   MT-CO2  34.175087        2.794080  5.670646e-256  4.457128e-253
# 4   MT-CO1  33.537945        2.749732  1.349542e-246  8.485921e-244
#       gene  logfoldchanges           pval  Wilcoxon_adj_pval
# 0  MT-ND4L        3.637189   0.000000e+00       0.000000e+00
# 1  MT-ATP8        3.875587   0.000000e+00       0.000000e+00
# 2   MT-ND6        3.291033  1.646604e-291      1.725641e-288
# 3   MT-CO2        2.794080  5.670646e-256      4.457128e-253
# 4   MT-CO1        2.749732  1.349542e-246      8.485921e-244

# %%
df_wilcoxon.head(2)
# Out:
#       gene  logfoldchanges  pval  Wilcoxon_adj_pval
# 0  MT-ND4L        3.637189   0.0                0.0
# 1  MT-ATP8        3.875587   0.0                0.0

# %%
# 2. DEG_limatrend 전처리 
# limatrend_DEG : limmatrend_DEG_~.csv

df_limmatrend = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_limmatrend//limmatrend_DEG_epithelial_re.csv')
print(df_limmatrend.shape)
print(df_limmatrend.head(2))
df_limmatrend = df_limmatrend[["names", "logfoldchanges", "pvals", "pvals_adj"]]
print((df_limmatrend.head()))
df_limmatrend.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "limmatrend_adj_pval"}, inplace=True)
print(df_limmatrend.head())
# Out:
# (3144, 6)
#      names          pvals      pvals_adj  logfoldchanges  neglog10_pvalue  \
# 0  MT-ND4L  4.940656e-324  4.940656e-324       -2.217066              NaN
# 1  MT-ATP8  4.940656e-324  4.940656e-324       -1.765433              NaN
#
#    neglog10_adjpvalue
# 0                 NaN
# 1                 NaN
#      names  logfoldchanges          pvals      pvals_adj
# 0  MT-ND4L       -2.217066  4.940656e-324  4.940656e-324
# 1  MT-ATP8       -1.765433  4.940656e-324  4.940656e-324
# 2   MT-CO2       -2.248434  4.940656e-324  4.940656e-324
# 3   MT-CO1       -2.435055  4.940656e-324  4.940656e-324
# 4    RPL17       -0.789864  4.940656e-324  4.940656e-324
#       gene  logfoldchanges           pval  limmatrend_adj_pval
# 0  MT-ND4L       -2.217066  4.940656e-324        4.940656e-324
# 1  MT-ATP8       -1.765433  4.940656e-324        4.940656e-324
# 2   MT-CO2       -2.248434  4.940656e-324        4.940656e-324
# 3   MT-CO1       -2.435055  4.940656e-324        4.940656e-324
# 4    RPL17       -0.789864  4.940656e-324        4.940656e-324

# %%
df_limmatrend.head(2)
# Out:
#       gene  logfoldchanges           pval  limmatrend_adj_pval
# 0  MT-ND4L       -2.217066  4.940656e-324        4.940656e-324
# 1  MT-ATP8       -1.765433  4.940656e-324        4.940656e-324

# %%
# 3. RISCQP_DEG 전처리
# DEG_RISCQP : RISCQP_DEG_-.csv

df_RISCQP = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_RISCQP/RISCQP_DEG_Epithelial_re.csv')
print(df_RISCQP.shape)
print(df_RISCQP.head())
df_RISCQP = df_RISCQP[["Symbol", "log2FC", "Pvalue", "Padj"]]
df_RISCQP.rename(columns={"Symbol": "gene","Pvalue": "pval","Padj": "RISCQP_adj_pval"}, inplace=True)
print(df_RISCQP.head())
# Out:
# (3144, 10)
#   Unnamed: 0   Symbol  Percent  Pct.Ctl  Pct.Sam  avelog.Ctl  avelog.Sam  \
# 0    MT-ATP8  MT-ATP8    0.569    0.322    0.954    7.524093    2.323961
# 1    MT-ND4L  MT-ND4L    0.634    0.412    0.982    7.931826    3.025216
# 2     MT-ND6   MT-ND6    0.480    0.274    0.801    5.999098    1.873455
# 3     MT-CO2   MT-CO2    0.708    0.525    0.995    8.445374    4.431270
# 4     MT-CYB   MT-CYB    0.710    0.529    0.993    8.376577    4.421839
#
#      log2FC         Pvalue           Padj
# 0 -7.650043   0.000000e+00   0.000000e+00
# 1 -7.150020   0.000000e+00   0.000000e+00
# 2 -6.189037  3.845153e-266  4.029720e-263
# 3 -5.808088  3.201642e-241  2.516491e-238
# 4 -5.722583  5.416784e-239  3.406074e-236
#       gene    log2FC           pval  RISCQP_adj_pval
# 0  MT-ATP8 -7.650043   0.000000e+00     0.000000e+00
# 1  MT-ND4L -7.150020   0.000000e+00     0.000000e+00
# 2   MT-ND6 -6.189037  3.845153e-266    4.029720e-263
# 3   MT-CO2 -5.808088  3.201642e-241    2.516491e-238
# 4   MT-CYB -5.722583  5.416784e-239    3.406074e-236

# %%
df_RISCQP.head(2)
# Out:
#       gene    log2FC  pval  RISCQP_adj_pval
# 0  MT-ATP8 -7.650043   0.0              0.0
# 1  MT-ND4L -7.150020   0.0              0.0

# %%
# 4. monocle_deg 전처리
# DEG_monocle : monocle_DEG_-.csv

df_monocle = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_monocle/monocle_DEG_epithelial.csv')
print(df_monocle.shape)
print(df_monocle.head())
df_monocle = df_monocle[["gene", "log2FC", "pvalue", "adjpvalue"]]
df_monocle.rename(columns={"pvalue": "pval","adjpvalue": "monocle_adj_pval"}, inplace=True)
print(df_monocle.head())
# Out:
# (3144, 13)
#    Unnamed: 0     gene  num_cells_expressed  gene_id status      term  \
# 0           1   MT-CO2                 3497   MT-CO2     OK  GroupMSI
# 1           2  MT-ATP8                 2807  MT-ATP8     OK  GroupMSI
# 2           3  MT-ND4L                 3132  MT-ND4L     OK  GroupMSI
# 3           4   MT-CYB                 3505   MT-CYB     OK  GroupMSI
# 4           5   MT-CO1                 3582   MT-CO1     OK  GroupMSI
#
#      log2FC   std_err   test_val         pvalue  normalized_effect  \
# 0  0.661903  0.017039  38.846643   0.000000e+00           0.951687
# 1  1.194655  0.027433  43.547632   0.000000e+00           1.707921
# 2  1.188133  0.024510  48.475817   0.000000e+00           1.701702
# 3  0.626960  0.017618  35.586235  2.287498e-277           0.901118
# 4  0.628702  0.017981  34.965716  7.472080e-268           0.904345
#
#   model_component      adjpvalue
# 0           count   0.000000e+00
# 1           count   0.000000e+00
# 2           count   0.000000e+00
# 3           count  7.185031e-274
# 4           count  2.346233e-264
#       gene    log2FC           pval  monocle_adj_pval
# 0   MT-CO2  0.661903   0.000000e+00      0.000000e+00
# 1  MT-ATP8  1.194655   0.000000e+00      0.000000e+00
# 2  MT-ND4L  1.188133   0.000000e+00      0.000000e+00
# 3   MT-CYB  0.626960  2.287498e-277     7.185031e-274
# 4   MT-CO1  0.628702  7.472080e-268     2.346233e-264

# %%
df_monocle.head(2)
# Out:
#       gene    log2FC  pval  monocle_adj_pval
# 0   MT-CO2  0.661903   0.0               0.0
# 1  MT-ATP8  1.194655   0.0               0.0

# %%
# 5. DEG_MAST 전처리 
# MAST_DEG : MAST_DEG_~.csv

df_MAST = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_MAST/MAST_DEG_Epithelial.csv')
print(df_MAST.shape)
print(df_MAST.head(2))
# df_MAST = df_MAST[["names", "logfoldchanges", "pvals", "pvals_adj"]]
# print((df_MAST.head()))
df_MAST.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "MAST_adj_pval"}, inplace=True)
print(df_MAST.head())
# Out:
# (3144, 4)
#    names  logfoldchanges         pvals     pvals_adj
# 0   A1CF        0.150993  6.329067e-50  7.803368e-49
# 1  AAMDC        0.037694  4.960838e-07  8.550918e-07
#     gene  logfoldchanges          pval  MAST_adj_pval
# 0   A1CF        0.150993  6.329067e-50   7.803368e-49
# 1  AAMDC        0.037694  4.960838e-07   8.550918e-07
# 2   AAMP        0.015448  9.344859e-02   1.051171e-01
# 3  ABCA5        0.066899  4.625613e-17   1.365533e-16
# 4  ABCC3        0.228836  9.873463e-61   1.753795e-59

# %%
df_MAST.head(2)
# Out:
#     gene  logfoldchanges          pval  MAST_adj_pval
# 0   A1CF        0.150993  6.329067e-50   7.803368e-49
# 1  AAMDC        0.037694  4.960838e-07   8.550918e-07

# %% [markdown]
# ## <font color="red">**MSS/MSI 데이터프레임**

# %%
import pandas as pd
from functools import reduce

# 1) 미리 각 df에서 gene + adj_pval 컬럼만 추출
dfs = [
    df_wilcoxon[["gene", "Wilcoxon_adj_pval"]],
    df_limmatrend[["gene", "limmatrend_adj_pval"]],
    df_RISCQP[["gene", "RISCQP_adj_pval"]],
    df_MAST[["gene", "MAST_adj_pval"]],
    df_monocle[["gene", "monocle_adj_pval"]],
]

# 2) Reduce를 이용해 순차적으로 outer merge
df_mmm = reduce(
    lambda left, right: pd.merge(left, right, on="gene", how="outer"),
    dfs
)

# 결과 확인
print(df_mmm.shape)
print(df_mmm.head())
# Out:
# (3144, 6)
#     gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0   A1CF       7.670553e-27         9.825311e-47     1.390769e-36
# 1  AAMDC       2.571067e-04         2.782628e-06     5.717027e-07
# 2   AAMP       1.503415e-01         3.909203e-02     6.223421e-02
# 3  ABCA5       2.038353e-09         3.148525e-15     5.589347e-16
# 4  ABCC3       4.374546e-44         2.198672e-57     2.543622e-50
#
#    MAST_adj_pval  monocle_adj_pval
# 0   7.803368e-49      2.050862e-12
# 1   8.550918e-07      1.000000e+00
# 2   1.051171e-01      1.000000e+00
# 3   1.365533e-16      6.750096e-04
# 4   1.753795e-59      5.374573e-17

# %%
df_mmm.head(2)
# Out:
#     gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0   A1CF       7.670553e-27         9.825311e-47     1.390769e-36
# 1  AAMDC       2.571067e-04         2.782628e-06     5.717027e-07
#
#    MAST_adj_pval  monocle_adj_pval
# 0   7.803368e-49      2.050862e-12
# 1   8.550918e-07      1.000000e+00

# %%
# 1) 각 컬럼별 rank 계산 (값이 작을수록 1위, NaN은 가장 마지막)
df_mmm['rank_wilcoxon'] = df_mmm['Wilcoxon_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_limma'] = df_mmm['limmatrend_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_RISCQP'] = df_mmm['RISCQP_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_MAST'] = df_mmm['MAST_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_monocle'] = df_mmm['monocle_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

# 2) 5개 rank의 합 계산
df_mmm['rank_sum'] = df_mmm[
    ['rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']
].sum(axis=1)

# 3) sum_rank 기준으로 정렬
df_mmm = df_mmm.sort_values('rank_sum').reset_index(drop=True)

# 결과 확인 (선택사항)
df_mmm
# Out:
#          gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0     MT-ATP8       0.000000e+00        4.940656e-324     0.000000e+00
# 1     MT-ND4L       0.000000e+00        4.940656e-324     0.000000e+00
# 2      MT-CO2      4.457128e-253        4.940656e-324    2.516491e-238
# 3      MT-CYB      4.842305e-232        4.940656e-324    3.406074e-236
# 4      MT-CO1      8.485921e-244        4.940656e-324    1.247759e-228
# ...       ...                ...                  ...              ...
# 3139  CARHSP1       8.960465e-01         9.063373e-01     9.890941e-01
# 3140    ZNF91       9.748932e-01         8.811283e-01     9.355832e-01
# 3141    EHMT1       9.703758e-01         8.770202e-01     9.688526e-01
# 3142    CASP6       9.432422e-01         9.714567e-01     9.414802e-01
# 3143    FBXO7       9.259428e-01         9.516168e-01     9.786478e-01
#
#       MAST_adj_pval  monocle_adj_pval  rank_wilcoxon  rank_limma  rank_RISCQP  \
# 0          0.000000      0.000000e+00              1           1            1
# 1          0.000000      0.000000e+00              1           1            1
# 2          0.000000      0.000000e+00              4           1            4
# 3          0.000000     7.185031e-274              8           1            5
# 4          0.000000     2.346233e-264              5           1            7
# ...             ...               ...            ...         ...          ...
# 3139       0.991250      1.000000e+00           3076        3103         3139
# 3140       0.980153      1.000000e+00           3127        3091         3103
# 3141       0.922950      1.000000e+00           3123        3087         3128
# 3142       0.953774      1.000000e+00           3109        3133         3108
# 3143       0.934471      1.000000e+00           3101        3128         3135
#
#       rank_MAST  rank_monocle  rank_sum
# 0             1             1         5
# 1             1             1         5
# 2             1             1        11
# 3             1             4        19
# 4             1             5        19
# ...         ...           ...       ...
# 3139       3144          1649     14111
# 3140       3142          1649     14112
# 3141       3127          1649     14114
# 3142       3139          1649     14138
# 3143       3132          1649     14145
#
# [3144 rows x 12 columns]

# %%
df_mmm_re = df_mmm[['rank_sum', 'gene', 'rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']]
df_mmm_re.head(20)
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 0          5  MT-ATP8              1           1            1          1
# 1          5  MT-ND4L              1           1            1          1
# 2         11   MT-CO2              4           1            4          1
# 3         19   MT-CYB              8           1            5          1
# 4         19   MT-CO1              5           1            7          1
# 5         20   MT-ND6              3           7            3          1
# 6         34    RPL17              7           1            6         13
# 7         51   MT-CO3             21          11           10          1
# 8         52   MT-ND5              9           8           11         14
# 9         66   MT-ND1             25          20            8          1
# 10        69    RPL26             12          12           18         18
# 11        74    CRIP1             20           9           16         15
# 12        75    H3-3A             11          15           15         17
# 13        81    RPL28              6          10           31         16
# 14        82    RPL39             13          16           21         21
# 15        82   MT-ND3             28          24            9          1
# 16        94      MIF             19          14           22         20
# 17        99  NDUFA13             15          13           17         19
# 18       113    RPLP1             10          22           39         27
# 19       127    EEF1G             55          17           20         22
#
#     rank_monocle
# 0              1
# 1              1
# 2              1
# 3              4
# 4              5
# 5              6
# 6              7
# 7              8
# 8             10
# 9             12
# 10             9
# 11            14
# 12            17
# 13            18
# 14            11
# 15            20
# 16            19
# 17            35
# 18            15
# 19            13

# %%
import pandas as pd
from functools import reduce

# 1️⃣ 각 메서드별 “gene + sign” DataFrame 생성
sign_dfs = []

# Wilcoxon: logfoldchanges >0 → MSI, <0 → MSS
sign_dfs.append(
    df_wilcoxon[['gene','logfoldchanges']]
    .assign(Wilcoxon_sign=lambda d: d['logfoldchanges'].gt(0).map({True:'MSI', False:'MSS'}))
    [['gene','Wilcoxon_sign']]
)

# limmatrend: log2FC <0 → MSI, >0 → MSS
sign_dfs.append(
    df_limmatrend[['gene','logfoldchanges']]
    .assign(limmat_sign=lambda d: d['logfoldchanges'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','limmat_sign']]
)

# RISCQP: log2FC <0 → MSI, >0 → MSS
sign_dfs.append(
    df_RISCQP[['gene','log2FC']]
    .assign(RISCQP_sign=lambda d: d['log2FC'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','RISCQP_sign']]
)

# 


# # MAST: logfoldchanges >0 → MSI, <0 → MSS
# sign_dfs.append(
#     df_MAST[['gene','logfoldchanges']]
#     .assign(MAST_sign=lambda d: d['logfoldchanges'].gt(0).map({True:'MSI', False:'MSS'}))
#     [['gene','MAST_sign']]
# )

# MAST: logfoldchanges >0 → MSI, <0 → MSS
sign_dfs.append(
    df_MAST[['gene','logfoldchanges']]
    .assign(MAST_sign=lambda d: d['logfoldchanges'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','MAST_sign']]
)

# 2️⃣ 모든 sign DataFrame outer merge
sign_df = reduce(lambda a,b: pd.merge(a,b,on='gene',how='outer'), sign_dfs)

# 3️⃣ rank 합계 df와 결합
df_final = df_mmm_re.merge(sign_df, on='gene', how='left')

# 4️⃣ consensus: MSI_sign이 3개 이상 → MSI_high, else MSS_high
sign_cols = [col for col in df_final.columns if col.endswith('_sign')]
df_final['consensus'] = df_final[sign_cols].apply(
    lambda row: 'MSI_high' if (row=='MSI').sum() >= 3 else 'MSS_high',
    axis=1
)

# 5️⃣ 결과 확인 (상위 20개)
print(df_final.sort_values('rank_sum').head(20))
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 0          5  MT-ATP8              1           1            1          1
# 1          5  MT-ND4L              1           1            1          1
# 2         11   MT-CO2              4           1            4          1
# 4         19   MT-CO1              5           1            7          1
# 3         19   MT-CYB              8           1            5          1
# 5         20   MT-ND6              3           7            3          1
# 6         34    RPL17              7           1            6         13
# 7         51   MT-CO3             21          11           10          1
# 8         52   MT-ND5              9           8           11         14
# 9         66   MT-ND1             25          20            8          1
# 10        69    RPL26             12          12           18         18
# 11        74    CRIP1             20           9           16         15
# 12        75    H3-3A             11          15           15         17
# 13        81    RPL28              6          10           31         16
# 14        82    RPL39             13          16           21         21
# 15        82   MT-ND3             28          24            9          1
# 16        94      MIF             19          14           22         20
# 17        99  NDUFA13             15          13           17         19
# 18       113    RPLP1             10          22           39         27
# 19       127    EEF1G             55          17           20         22
#
#     rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus
# 0              1           MSI         MSI         MSI       MSI  MSI_high
# 1              1           MSI         MSI         MSI       MSI  MSI_high
# 2              1           MSI         MSI         MSI       MSI  MSI_high
# 4              5           MSI         MSI         MSI       MSI  MSI_high
# 3              4           MSI         MSI         MSI       MSI  MSI_high
# 5              6           MSI         MSI         MSI       MSI  MSI_high
# 6              7           MSI         MSI         MSI       MSI  MSI_high
# 7              8           MSI         MSI         MSI       MSI  MSI_high
# 8             10           MSI         MSI         MSI       MSI  MSI_high
# 9             12           MSI         MSI         MSI       MSI  MSI_high
# 10             9           MSI         MSI         MSI       MSI  MSI_high
# 11            14           MSI         MSI         MSI       MSI  MSI_high
# 12            17           MSI         MSI         MSI       MSI  MSI_high
# 13            18           MSI         MSI         MSI       MSI  MSI_high
# 14            11           MSI         MSI         MSI       MSI  MSI_high
# 15            20           MSI         MSI         MSI       MSI  MSI_high
# 16            19           MSI         MSI         MSI       MSI  MSI_high
# 17            35           MSI         MSI         MSI       MSI  MSI_high
# 18            15           MSI         MSI         MSI       MSI  MSI_high
# 19            13           MSI         MSI         MSI       MSI  MSI_high

# %%
# 원하는 순서의 리스트
genes_of_interest = ["VSIG4", "LYVE1", "CLEC5A", "CX3CR1", "FN1", "IL11", "NRAP", "SDC1", "SCG5"]
df_final_filtered = df_final[df_final["gene"].isin(genes_of_interest)]
df_final_filtered

# 2) gene을 인덱스로 설정한 뒤 순서대로 선택
# df_final_filtered = (
#     df_final_filtered
#     .set_index('gene')
#     .loc[genes_of_interest]         # order 순서대로 행 재정렬
#     .reset_index()                  # 다시 gene을 컬럼으로
# )

df_final_filtered
# Out:
#       rank_sum  gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 1539      7638  SDC1           1751        1243         1622       1373
#
#       rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus
# 1539          1649           MSS         MSS         MSS       MSS  MSS_high

# %%
# 사용할 컬럼 리스트
rank_cols = ['rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST']

# # rank_mean 컬럼 생성: 행(row) 단위로 평균 계산
# df_final_filtered['rank_mean'] = df_final_filtered[rank_cols].mean(axis=1)

# rank_mean 컬럼 생성: 행(row) 단위로 평균 계산
df_final_filtered['rank_mean'] = (
    df_final_filtered[rank_cols]
    .mean(axis=1)          # 평균 계산
    .round()               # 소수 첫째 자리 반올림
    .astype(int)           # 정수형 변환
)

df_final_filtered
# Out:
# /tmp/ipykernel_1187713/45665166.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_filtered['rank_mean'] = (
#       rank_sum  gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 1539      7638  SDC1           1751        1243         1622       1373
#
#       rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus  \
# 1539          1649           MSS         MSS         MSS       MSS  MSS_high
#
#       rank_mean
# 1539       1497
