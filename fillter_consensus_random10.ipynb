# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 정제

# %%
# 1. DEG_Wilcoxon 전처리 
# Wilcoxon_DEG : Wilcoxon_DEG_~.csv

df_wilcoxon = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_Wilcoxon/Wilcoxon_DEG_random10_re.csv')
print(df_wilcoxon.shape)
print(df_wilcoxon.head())
df_wilcoxon = df_wilcoxon[["names", "logfoldchanges", "pvals", "pvals_adj"]]
df_wilcoxon.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "Wilcoxon_adj_pval"}, inplace=True)
print(df_wilcoxon.head())
# Out:
# (8177, 5)
#     names     scores  logfoldchanges          pvals      pvals_adj
# 0  RPL13A  28.330397        2.672939  1.459844e-176  1.193714e-172
# 1   RPS11  27.693296        2.192736  8.408641e-169  3.437873e-165
# 2    RPS2  26.615640        2.582640  4.474600e-156  1.219627e-152
# 3   RPS10  25.069100        5.119965  1.080962e-138  1.104878e-135
# 4   RPS20  23.610120        2.750181  3.033728e-123  2.255163e-120
#      gene  logfoldchanges           pval  Wilcoxon_adj_pval
# 0  RPL13A        2.672939  1.459844e-176      1.193714e-172
# 1   RPS11        2.192736  8.408641e-169      3.437873e-165
# 2    RPS2        2.582640  4.474600e-156      1.219627e-152
# 3   RPS10        5.119965  1.080962e-138      1.104878e-135
# 4   RPS20        2.750181  3.033728e-123      2.255163e-120

# %%
df_wilcoxon.head(2)
# Out:
#      gene  logfoldchanges           pval  Wilcoxon_adj_pval
# 0  RPL13A        2.672939  1.459844e-176      1.193714e-172
# 1   RPS11        2.192736  8.408641e-169      3.437873e-165

# %%
# 2. DEG_limatrend 전처리 
# limatrend_DEG : limmatrend_DEG_~.csv

df_limmatrend = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_limmatrend//limmatrend_DEG_random10_re.csv')
print(df_limmatrend.shape)
print(df_limmatrend.head(2))
df_limmatrend = df_limmatrend[["names", "logfoldchanges", "pvals", "pvals_adj"]]
print((df_limmatrend.head()))
df_limmatrend.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "limmatrend_adj_pval"}, inplace=True)
print(df_limmatrend.head())
# Out:
# (8177, 6)
#     names          pvals      pvals_adj  logfoldchanges  neglog10_pvalue  \
# 0   RPS10  4.940656e-324  4.940656e-324       -0.865380              NaN
# 1  RPL13A  7.130062e-273  2.915126e-269       -1.309928       272.146907
#
#    neglog10_adjpvalue
# 0                 NaN
# 1          268.535343
#     names  logfoldchanges          pvals      pvals_adj
# 0   RPS10       -0.865380  4.940656e-324  4.940656e-324
# 1  RPL13A       -1.309928  7.130062e-273  2.915126e-269
# 2   RPS11       -0.926150  9.604206e-233  2.617787e-229
# 3   RPS20       -0.852454  1.649637e-223  3.372271e-220
# 4   RPL21       -1.071764  2.962906e-213  4.845537e-210
#      gene  logfoldchanges           pval  limmatrend_adj_pval
# 0   RPS10       -0.865380  4.940656e-324        4.940656e-324
# 1  RPL13A       -1.309928  7.130062e-273        2.915126e-269
# 2   RPS11       -0.926150  9.604206e-233        2.617787e-229
# 3   RPS20       -0.852454  1.649637e-223        3.372271e-220
# 4   RPL21       -1.071764  2.962906e-213        4.845537e-210

# %%
df_limmatrend.head(2)
# Out:
#      gene  logfoldchanges           pval  limmatrend_adj_pval
# 0   RPS10       -0.865380  4.940656e-324        4.940656e-324
# 1  RPL13A       -1.309928  7.130062e-273        2.915126e-269

# %%
# 3. RISCQP_DEG 전처리
# DEG_RISCQP : RISCQP_DEG_-.csv

df_RISCQP = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_RISCQP/RISCQP_DEG_random10_re.csv')
print(df_RISCQP.shape)
print(df_RISCQP.head())
df_RISCQP = df_RISCQP[["Symbol", "log2FC", "Pvalue", "Padj"]]
df_RISCQP.rename(columns={"Symbol": "gene","Pvalue": "pval","Padj": "RISCQP_adj_pval"}, inplace=True)
print(df_RISCQP.head())
# Out:
# (8177, 10)
#   Unnamed: 0   Symbol  Percent  Pct.Ctl  Pct.Sam  avelog.Ctl  avelog.Sam  \
# 0      RPS10    RPS10    0.409    0.296    0.758    5.015100    1.417054
# 1    ATP6V0C  ATP6V0C    0.691    0.842    0.226    1.357934    5.113375
# 2       NME2     NME2    0.763    0.885    0.386    2.374503    5.960684
# 3       CD24     CD24    0.686    0.832    0.239    1.564979    5.491573
# 4    HLA-DRA  HLA-DRA    0.278    0.164    0.629    4.088404    0.850160
#
#      log2FC         Pvalue           Padj
# 0 -5.581819  4.467426e-160  3.653015e-156
# 1  5.838189  1.010787e-150  4.132604e-147
# 2  5.310964  4.259320e-141  1.160949e-137
# 3  5.997337  5.959174e-139  1.218204e-135
# 4 -5.451671  9.803632e-131  1.603286e-127
#       gene    log2FC           pval  RISCQP_adj_pval
# 0    RPS10 -5.581819  4.467426e-160    3.653015e-156
# 1  ATP6V0C  5.838189  1.010787e-150    4.132604e-147
# 2     NME2  5.310964  4.259320e-141    1.160949e-137
# 3     CD24  5.997337  5.959174e-139    1.218204e-135
# 4  HLA-DRA -5.451671  9.803632e-131    1.603286e-127

# %%
df_RISCQP.head(2)
# Out:
#       gene    log2FC           pval  RISCQP_adj_pval
# 0    RPS10 -5.581819  4.467426e-160    3.653015e-156
# 1  ATP6V0C  5.838189  1.010787e-150    4.132604e-147

# %%
# 4. monocle_deg 전처리
# DEG_monocle : monocle_DEG_-.csv

df_monocle = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_monocle/monocle_DEG_random10.csv')
print(df_monocle.shape)
print(df_monocle.head())
df_monocle = df_monocle[["gene", "log2FC", "pvalue", "adjpvalue"]]
df_monocle.rename(columns={"pvalue": "pval","adjpvalue": "monocle_adj_pval"}, inplace=True)
print(df_monocle.head())
# Out:
# (8176, 13)
#    Unnamed: 0    gene  num_cells_expressed          gene_id status      term  \
# 0           1    RPS2                 1875  ENSG00000140988     OK  GroupMSI
# 1           2  RPL13A                 1872  ENSG00000142541     OK  GroupMSI
# 2           3   RPS10                 1139  ENSG00000124614     OK  GroupMSI
# 3           4   RPL21                 1821  ENSG00000122026     OK  GroupMSI
# 4           5  MT-CO3                 1872  ENSG00000198938     OK  GroupMSI
#
#      log2FC   std_err   test_val         pvalue  normalized_effect  \
# 0  1.030028  0.034472  29.880115  3.567735e-196           1.475453
# 1  1.140854  0.038439  29.679532  1.410927e-193           1.631265
# 2  3.056965  0.114741  26.642307  2.197519e-156           4.115924
# 3  1.165155  0.043863  26.563407  1.797954e-155           1.661424
# 4  0.794580  0.030800  25.798017  9.333254e-147           1.142170
#
#   model_component      adjpvalue
# 0           count  2.916980e-192
# 1           count  1.153433e-189
# 2           count  1.796252e-152
# 3           count  1.469467e-151
# 4           count  7.627136e-143
#      gene    log2FC           pval  monocle_adj_pval
# 0    RPS2  1.030028  3.567735e-196     2.916980e-192
# 1  RPL13A  1.140854  1.410927e-193     1.153433e-189
# 2   RPS10  3.056965  2.197519e-156     1.796252e-152
# 3   RPL21  1.165155  1.797954e-155     1.469467e-151
# 4  MT-CO3  0.794580  9.333254e-147     7.627136e-143

# %%
df_monocle.head(2)
# Out:
#      gene    log2FC           pval  monocle_adj_pval
# 0    RPS2  1.030028  3.567735e-196     2.916980e-192
# 1  RPL13A  1.140854  1.410927e-193     1.153433e-189

# %%
# 5. DEG_MAST 전처리 
# MAST_DEG : MAST_DEG_~.csv

df_MAST = pd.read_csv('/nas/arpa_h_repository/public_data/CRC_Atlas_1/CRC-Atlas-Split/crc-atlas/Deg_data/DEG_MAST/MAST_DEG_random10.csv')
# df_MAST = pd.read_csv('/data/project/yeonu/consensus/filtered/plot/MAST_DEG_random.csv')
print(df_MAST.shape)
print(df_MAST.head(2))
# df_MAST = df_MAST[["names", "logfoldchanges", "pvals", "pvals_adj"]]
# print((df_MAST.head()))
df_MAST.rename(columns={"names": "gene","pvals": "pval","pvals_adj": "MAST_adj_pval"}, inplace=True)
print(df_MAST.head())
# Out:
# (8177, 4)
#     names  logfoldchanges  pvals  pvals_adj
# 0  RPL13A       -1.822027    0.0        0.0
# 1   RPS10       -1.064578    0.0        0.0
#       gene  logfoldchanges           pval  MAST_adj_pval
# 0   RPL13A       -1.822027   0.000000e+00   0.000000e+00
# 1    RPS10       -1.064578   0.000000e+00   0.000000e+00
# 2    RPS11       -1.554288  1.921537e-279  5.237470e-276
# 3  RPL22L1       -0.439248  1.859214e-269  3.800698e-266
# 4    RPS20       -1.165237  6.865009e-269  1.122704e-265

# %%
df_MAST.head(2)
# Out:
#      gene  logfoldchanges  pval  MAST_adj_pval
# 0  RPL13A       -1.822027   0.0            0.0
# 1   RPS10       -1.064578   0.0            0.0

# %% [markdown]
# ## <font color="red">**MSS/MSI 데이터프레임**

# %%
import pandas as pd
from functools import reduce

# 1) 미리 각 df에서 gene + adj_pval 컬럼만 추출
dfs = [
    df_wilcoxon[["gene", "Wilcoxon_adj_pval"]],
    df_limmatrend[["gene", "limmatrend_adj_pval"]],
    df_RISCQP[["gene", "RISCQP_adj_pval"]],
    df_MAST[["gene", "MAST_adj_pval"]],
    df_monocle[["gene", "monocle_adj_pval"]],
]

# 2) Reduce를 이용해 순차적으로 outer merge
df_mmm = reduce(
    lambda left, right: pd.merge(left, right, on="gene", how="outer"),
    dfs
)

# 결과 확인
print(df_mmm.shape)
print(df_mmm.head())
# Out:
# (8177, 6)
#     gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0   A1CF           0.000002         6.344713e-12     4.205538e-10
# 1   AAAS           0.000090         5.280448e-05     3.439243e-05
# 2   AACS           0.520035         9.602669e-01     2.045692e-01
# 3  AAGAB           0.148731         1.203235e-01     3.086051e-01
# 4   AAK1           0.037375         1.005317e-01     2.240574e-02
#
#    MAST_adj_pval  monocle_adj_pval
# 0   1.795429e-07               1.0
# 1   3.661982e-03               1.0
# 2   2.867077e-06               1.0
# 3   8.436273e-04               1.0
# 4   3.563532e-07               1.0

# %%
df_mmm.head(2)
# Out:
#    gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0  A1CF           0.000002         6.344713e-12     4.205538e-10
# 1  AAAS           0.000090         5.280448e-05     3.439243e-05
#
#    MAST_adj_pval  monocle_adj_pval
# 0   1.795429e-07               1.0
# 1   3.661982e-03               1.0

# %%
# 1) 각 컬럼별 rank 계산 (값이 작을수록 1위, NaN은 가장 마지막)
df_mmm['rank_wilcoxon'] = df_mmm['Wilcoxon_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_limma'] = df_mmm['limmatrend_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_RISCQP'] = df_mmm['RISCQP_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_MAST'] = df_mmm['MAST_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

df_mmm['rank_monocle'] = df_mmm['monocle_adj_pval'] \
    .rank(method='min', ascending=True, na_option='bottom').astype(int)

# 2) 5개 rank의 합 계산
df_mmm['rank_sum'] = df_mmm[
    ['rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']
].sum(axis=1)

# 3) sum_rank 기준으로 정렬
df_mmm = df_mmm.sort_values('rank_sum').reset_index(drop=True)

# 결과 확인 (선택사항)
df_mmm
# Out:
#          gene  Wilcoxon_adj_pval  limmatrend_adj_pval  RISCQP_adj_pval  \
# 0       RPS10      1.104878e-135        4.940656e-324    3.653015e-156
# 1      RPL13A      1.193714e-172        2.915126e-269     7.925960e-65
# 2       RPS20      2.255163e-120        3.372271e-220     4.987850e-72
# 3        RPS2      1.219627e-152        2.308968e-202     2.314224e-61
# 4        MUC2       2.062973e-81        7.873603e-181    1.140427e-114
# ...       ...                ...                  ...              ...
# 8172    PLOD1       9.900171e-01         9.011326e-01     8.745719e-01
# 8173   MINDY3       8.356917e-01         9.481515e-01     8.770946e-01
# 8174   IL17RC       7.906843e-01         9.413090e-01     7.047627e-01
# 8175  PITPNC1       9.984062e-01         9.862065e-01     9.719609e-01
# 8176  SEPTIN8       8.843754e-01         9.480148e-01     9.301816e-01
#
#       MAST_adj_pval  monocle_adj_pval  rank_wilcoxon  rank_limma  rank_RISCQP  \
# 0      0.000000e+00     1.796252e-152              8           1            1
# 1      0.000000e+00     1.153433e-189              1           2           47
# 2     1.122704e-265     4.092154e-133             11           4           34
# 3     1.041658e-245     2.916980e-192              3           6           56
# 4     4.387857e-206     7.076728e-142             38          10            8
# ...             ...               ...            ...         ...          ...
# 8172   2.412851e-01      1.000000e+00           8155        7979         8021
# 8173   3.301549e-01      1.000000e+00           7919        8071         8023
# 8174   6.451843e-01      1.000000e+00           7822        8060         7744
# 8175   3.358408e-01      1.000000e+00           8175        8142         8141
# 8176   7.050925e-01      1.000000e+00           7987        8070         8093
#
#       rank_MAST  rank_monocle  rank_sum
# 0             1             3        14
# 1             1             2        53
# 2             5            10        64
# 3             8             1        74
# 4            12             6        74
# ...         ...           ...       ...
# 8172       7078          1403     32636
# 8173       7313          1403     32729
# 8174       7833          1403     32862
# 8175       7328          1403     33189
# 8176       7901          1403     33454
#
# [8177 rows x 12 columns]

# %%
df_mmm_re = df_mmm[['rank_sum', 'gene', 'rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST', 'rank_monocle']]
df_mmm_re.head(20)
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 0         14    RPS10              8           1            1          1
# 1         53   RPL13A              1           2           47          1
# 2         64    RPS20             11           4           34          5
# 3         74     RPS2              3           6           56          8
# 4         74     MUC2             38          10            8         12
# 5         82    FCGBP             44           9            6         11
# 6         91    RPL21             12           5           61          9
# 7         94    RPS11              2           3           77          3
# 8         98     PIGR             32          20            7         18
# 9        109     CD24              5          33            4         22
# 10       123  HLA-DRA             26           8            5         69
# 11       128     REG4             50          27           29         15
# 12       134     RPL7             13          15           69         24
# 13       151    PPDPF              9          17           22         29
# 14       168  ATP6V0C              4          23            2         19
# 15       182    RPL23             19          14           98         13
# 16       186   PABPC1             10          22           12         52
# 17       197     NME2             14          41            3         46
# 18       203    RPS29             28          18          121         16
# 19       220   MT-ND2             29          42           83         55
#
#     rank_monocle
# 0              3
# 1              2
# 2             10
# 3              1
# 4              6
# 5             12
# 6              4
# 7              9
# 8             21
# 9             45
# 10            15
# 11             7
# 12            13
# 13            74
# 14           120
# 15            38
# 16            90
# 17            93
# 18            20
# 19            11

# %%
import pandas as pd
from functools import reduce

# 1️⃣ 각 메서드별 “gene + sign” DataFrame 생성
sign_dfs = []

# Wilcoxon: logfoldchanges >0 → MSI, <0 → MSS
sign_dfs.append(
    df_wilcoxon[['gene','logfoldchanges']]
    .assign(Wilcoxon_sign=lambda d: d['logfoldchanges'].gt(0).map({True:'MSI', False:'MSS'}))
    [['gene','Wilcoxon_sign']]
)

# limmatrend: log2FC <0 → MSI, >0 → MSS
sign_dfs.append(
    df_limmatrend[['gene','logfoldchanges']]
    .assign(limmat_sign=lambda d: d['logfoldchanges'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','limmat_sign']]
)

# RISCQP: log2FC <0 → MSI, >0 → MSS
sign_dfs.append(
    df_RISCQP[['gene','log2FC']]
    .assign(RISCQP_sign=lambda d: d['log2FC'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','RISCQP_sign']]
)

# 


# # MAST: logfoldchanges >0 → MSI, <0 → MSS
# sign_dfs.append(
#     df_MAST[['gene','logfoldchanges']]
#     .assign(MAST_sign=lambda d: d['logfoldchanges'].gt(0).map({True:'MSI', False:'MSS'}))
#     [['gene','MAST_sign']]
# )

# MAST: logfoldchanges >0 → MSI, <0 → MSS
sign_dfs.append(
    df_MAST[['gene','logfoldchanges']]
    .assign(MAST_sign=lambda d: d['logfoldchanges'].lt(0).map({True:'MSI', False:'MSS'}))
    [['gene','MAST_sign']]
)

# 2️⃣ 모든 sign DataFrame outer merge
sign_df = reduce(lambda a,b: pd.merge(a,b,on='gene',how='outer'), sign_dfs)

# 3️⃣ rank 합계 df와 결합
df_final = df_mmm_re.merge(sign_df, on='gene', how='left')

# 4️⃣ consensus: MSI_sign이 3개 이상 → MSI_high, else MSS_high
sign_cols = [col for col in df_final.columns if col.endswith('_sign')]
df_final['consensus'] = df_final[sign_cols].apply(
    lambda row: 'MSI_high' if (row=='MSI').sum() >= 3 else 'MSS_high',
    axis=1
)

# 5️⃣ 결과 확인 (상위 20개)
print(df_final.sort_values('rank_sum').head(20))
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 0         14    RPS10              8           1            1          1
# 1         53   RPL13A              1           2           47          1
# 2         64    RPS20             11           4           34          5
# 3         74     RPS2              3           6           56          8
# 4         74     MUC2             38          10            8         12
# 5         82    FCGBP             44           9            6         11
# 6         91    RPL21             12           5           61          9
# 7         94    RPS11              2           3           77          3
# 8         98     PIGR             32          20            7         18
# 9        109     CD24              5          33            4         22
# 10       123  HLA-DRA             26           8            5         69
# 11       128     REG4             50          27           29         15
# 12       134     RPL7             13          15           69         24
# 13       151    PPDPF              9          17           22         29
# 14       168  ATP6V0C              4          23            2         19
# 15       182    RPL23             19          14           98         13
# 16       186   PABPC1             10          22           12         52
# 17       197     NME2             14          41            3         46
# 18       203    RPS29             28          18          121         16
# 19       220   MT-ND2             29          42           83         55
#
#     rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus
# 0              3           MSI         MSI         MSI       MSI  MSI_high
# 1              2           MSI         MSI         MSI       MSI  MSI_high
# 2             10           MSI         MSI         MSI       MSI  MSI_high
# 3              1           MSI         MSI         MSI       MSI  MSI_high
# 4              6           MSI         MSI         MSI       MSI  MSI_high
# 5             12           MSI         MSI         MSI       MSI  MSI_high
# 6              4           MSI         MSI         MSI       MSI  MSI_high
# 7              9           MSI         MSI         MSI       MSI  MSI_high
# 8             21           MSI         MSI         MSI       MSI  MSI_high
# 9             45           MSS         MSS         MSS       MSS  MSS_high
# 10            15           MSI         MSI         MSI       MSI  MSI_high
# 11             7           MSI         MSI         MSI       MSI  MSI_high
# 12            13           MSI         MSI         MSI       MSI  MSI_high
# 13            74           MSS         MSS         MSS       MSS  MSS_high
# 14           120           MSS         MSS         MSS       MSS  MSS_high
# 15            38           MSI         MSI         MSI       MSI  MSI_high
# 16            90           MSS         MSS         MSS       MSS  MSS_high
# 17            93           MSS         MSS         MSS       MSS  MSS_high
# 18            20           MSI         MSI         MSI       MSI  MSI_high
# 19            11           MSI         MSI         MSI       MSI  MSI_high

# %%
df_final.head(20)
# Out:
#     rank_sum     gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 0         14    RPS10              8           1            1          1
# 1         53   RPL13A              1           2           47          1
# 2         64    RPS20             11           4           34          5
# 3         74     RPS2              3           6           56          8
# 4         74     MUC2             38          10            8         12
# 5         82    FCGBP             44           9            6         11
# 6         91    RPL21             12           5           61          9
# 7         94    RPS11              2           3           77          3
# 8         98     PIGR             32          20            7         18
# 9        109     CD24              5          33            4         22
# 10       123  HLA-DRA             26           8            5         69
# 11       128     REG4             50          27           29         15
# 12       134     RPL7             13          15           69         24
# 13       151    PPDPF              9          17           22         29
# 14       168  ATP6V0C              4          23            2         19
# 15       182    RPL23             19          14           98         13
# 16       186   PABPC1             10          22           12         52
# 17       197     NME2             14          41            3         46
# 18       203    RPS29             28          18          121         16
# 19       220   MT-ND2             29          42           83         55
#
#     rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus
# 0              3           MSI         MSI         MSI       MSI  MSI_high
# 1              2           MSI         MSI         MSI       MSI  MSI_high
# 2             10           MSI         MSI         MSI       MSI  MSI_high
# 3              1           MSI         MSI         MSI       MSI  MSI_high
# 4              6           MSI         MSI         MSI       MSI  MSI_high
# 5             12           MSI         MSI         MSI       MSI  MSI_high
# 6              4           MSI         MSI         MSI       MSI  MSI_high
# 7              9           MSI         MSI         MSI       MSI  MSI_high
# 8             21           MSI         MSI         MSI       MSI  MSI_high
# 9             45           MSS         MSS         MSS       MSS  MSS_high
# 10            15           MSI         MSI         MSI       MSI  MSI_high
# 11             7           MSI         MSI         MSI       MSI  MSI_high
# 12            13           MSI         MSI         MSI       MSI  MSI_high
# 13            74           MSS         MSS         MSS       MSS  MSS_high
# 14           120           MSS         MSS         MSS       MSS  MSS_high
# 15            38           MSI         MSI         MSI       MSI  MSI_high
# 16            90           MSS         MSS         MSS       MSS  MSS_high
# 17            93           MSS         MSS         MSS       MSS  MSS_high
# 18            20           MSI         MSI         MSI       MSI  MSI_high
# 19            11           MSI         MSI         MSI       MSI  MSI_high

# %%
# 원하는 순서의 리스트
genes_of_interest = ["VSIG4", "LYVE1", "CLEC5A", "CX3CR1", "FN1", "IL11", "NRAP", "SDC1", "SCG5"]
df_final_filtered = df_final[df_final["gene"].isin(genes_of_interest)]
df_final_filtered

# 2) gene을 인덱스로 설정한 뒤 순서대로 선택
# df_final_filtered = (
#     df_final_filtered
#     .set_index('gene')
#     .loc[genes_of_interest]         # order 순서대로 행 재정렬
#     .reset_index()                  # 다시 gene을 컬럼으로
# )

df_final_filtered
# Out:
#       rank_sum  gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 1747      9517  SDC1           1245        1334         1539       3996
#
#       rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus
# 1747          1403           MSS         MSS         MSS       MSI  MSS_high

# %%
# 사용할 컬럼 리스트
rank_cols = ['rank_wilcoxon', 'rank_limma', 'rank_RISCQP', 'rank_MAST']

# # rank_mean 컬럼 생성: 행(row) 단위로 평균 계산
# df_final_filtered['rank_mean'] = df_final_filtered[rank_cols].mean(axis=1)

# rank_mean 컬럼 생성: 행(row) 단위로 평균 계산
df_final_filtered['rank_mean'] = (
    df_final_filtered[rank_cols]
    .mean(axis=1)          # 평균 계산
    .round()               # 소수 첫째 자리 반올림
    .astype(int)           # 정수형 변환
)

df_final_filtered
# Out:
# /tmp/ipykernel_1186304/45665166.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_filtered['rank_mean'] = (
#       rank_sum  gene  rank_wilcoxon  rank_limma  rank_RISCQP  rank_MAST  \
# 1747      9517  SDC1           1245        1334         1539       3996
#
#       rank_monocle Wilcoxon_sign limmat_sign RISCQP_sign MAST_sign consensus  \
# 1747          1403           MSS         MSS         MSS       MSI  MSS_high
#
#       rank_mean
# 1747       2028
